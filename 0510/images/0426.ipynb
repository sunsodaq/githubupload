# %%
a=5

# %%
a=a+3
a
# Out:
# 8

# %% [markdown]
# <h1>리스트</h1>

# %%
list1=[1,2,3,3,4,5,6]

# %%
total=0
for i in list1:
    total += i
print(total)
# Out:
# 24

# %%
#list1 의 짝수와 홀수의 합을 각각 구하세요

# %%
evenSum=0;
oddSum=0;
for i in list1:
    if(i%2==0):
        evenSum += i
    else:
        oddSum += i
evenSum, oddSum
# Out:
# (12, 12)

# %% [markdown]
# <h1 style="color:blue;">딕셔너리</h1>

# %%
obj={"a":"이은석", "b":"강예림", "c":["이진우","송우진","신선희","김휘완","이영채","김다원","빈중권"]}

# %%
obj
# Out:
# {'a': '이은석',
#  'b': '강예림',
#  'c': ['이진우', '송우진', '신선희s', '김휘완kk', '이영채', '김다원', '빈중권']}

# %%
for i in obj['c']:
    print(len(i))
# Out:
# 3
# 3
# 4
# 5
# 3
# 3
# 3

# %%
total=0
for i in obj['c']:
    total += len(i)
total
# Out:
# 21

# %%
def f(i):
    return 5*i

# %%
f(3)
# Out:
# 15

# %%
# 문자열을 받아서 문자열의 길이를 반환하는 함수 생성

# %%
def str(i):
    return len(i)

# %%
str("안녕하세요")
# Out:
# 5

# %%
str(obj['c'][1])
# Out:
# 3

# %%
list(map(lambda i : i*3, [1,2,3,5]))
# Out:
# [3, 6, 9, 15]

# %%
list(filter(lambda i : i%2==0, [1,2,3,5]))
# Out:
# [2]

# %% [markdown]
# ## 리스트 컴플릿핸션

# %%
list_fn = [ lambda i : i*2,  lambda i : i*3,  lambda i : i*4]

# %%
list(map(lambda i : i(5) , list_fn))
# Out:
# [10, 15, 20]

# %%
[i*2 for i in [1,2,3,5]]
# Out:
# [2, 4, 6, 10]

# %%
obj={"a":"이은석", "b":"강예림", "c":["이진우","송우진","신선희","김휘완","이영채","김다원","빈중권"]}

# %%
def fn_obj_c(i): return i['c']

# %%
fn_obj_c(obj)
# Out:
# ['이진우', '송우진', '신선희', '김휘완', '이영채', '김다원', '빈중권']

# %% [markdown]
# <ul>
#     <li>numpy:수치해석</li>
#     <li>pandas:데이터 분석</li>
#     <li>matplotlib:시각화</li>
# </ul>

# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
list2=[3,4,5,11,56]
#각각의 데이터의 5배를 한다
# [i*5 for i in list2]
nplist = np.array(list2)

# %%
nplist*5 # 위의 [i*5 for i in list2] 과 같은 코드
# Out:
# array([ 15,  20,  25,  55, 280])

# %%
np.log(nplist)
# Out:
# array([1.09861229, 1.38629436, 1.60943791, 2.39789527, 4.02535169])

# %%
np.log10(10)
# Out:
# 1.0

# %%
np.log2(8)
# Out:
# 3.0

# %%
import matplotlib.pyplot as plt

# %%
xx=np.linspace(-10,10,100) #1에서 100까지의 100개의 점 생성
y_sin=np.sin(xx) #-1 ~ 1 사이의 값
y_cos=np.cos(xx)

# %%
#그래프 그리기
plt.figure(figsize=(8,6))
plt.plot(xx,y_sin, label='sin(x)')
plt.plot(xx,y_cos, label='cos(x)')
plt.xlabel('X')
plt.ylabel('Y')
plt.title("sine and cos wave graph")
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x236856aa790>,
# ...
#  [Text(0.9801071672559598, 0.4993895680663527, 'Frogs'),
#   Text(-0.33991877217145816, 1.046162142464278, 'Hogs'),
#   Text(-0.49938947630209474, -0.9801072140121813, 'Dogs'),
#   Text(1.0461621822461364, -0.3399186497354948, 'Logs')])

# %%
import matplotlib.pyplot as plt
import numpy as np

ax = plt.figure().add_subplot(projection='3d')

# Plot a sin curve using the x and y axes.
x = np.linspace(0, 1, 100)
y = np.sin(x * 2 * np.pi) / 2 + 0.5
ax.plot(x, y, zs=0, zdir='z', label='curve in (x, y)')

# Plot scatterplot data (20 2D points per colour) on the x and z axes.
colors = ('r', 'g', 'b', 'k')

# Fixing random state for reproducibility
np.random.seed(19680801)

x = np.random.sample(20 * len(colors))
y = np.random.sample(20 * len(colors))
c_list = []
for c in colors:
    c_list.extend([c] * 20)
# By using zdir='y', the y value of these points is fixed to the zs value 0
# and the (x, y) points are plotted on the x and z axes.
ax.scatter(x, y, zs=0, zdir='y', c=c_list, label='points in (x, z)')

# Make legend, set axes limits and labels
ax.legend()
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.set_zlim(0, 1)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Customize the view angle so it's easier to see that the scatter points lie
# on the plane y=0
ax.view_init(elev=20., azim=-35, roll=0)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

from matplotlib import cbook, cm
from matplotlib.colors import LightSource

# Load and format data
dem = cbook.get_sample_data('jacksboro_fault_dem.npz')
z = dem['elevation']
nrows, ncols = z.shape
x = np.linspace(dem['xmin'], dem['xmax'], ncols)
y = np.linspace(dem['ymin'], dem['ymax'], nrows)
x, y = np.meshgrid(x, y)

region = np.s_[5:50, 5:50]
x, y, z = x[region], y[region], z[region]

# Set up plot
fig, ax = plt.subplots(subplot_kw=dict(projection='3d'))

ls = LightSource(270, 45)
# To use a custom hillshading mode, override the built-in shading and pass
# in the rgb colors of the shaded surface calculated from "shade".
rgb = ls.shade(z, cmap=cm.gist_earth, vert_exag=0.1, blend_mode='soft')
surf = ax.plot_surface(x, y, z, rstride=1, cstride=1, facecolors=rgb,
                       linewidth=0, antialiased=False, shade=False)

plt.show()

# %%
plt.figure(figsize=(5,5))
plt.plot(x_sin,y_sin)
plt.xlabel('X')
plt.ylabel('log(x)')
plt.title("sine wave graph")
plt.grid(True)
plt.show()

# %% [markdown]
# $$   \lim_{h \to 0} \frac{f(x+h)-f(x)}{h}    $$
# $$  f(x) = x^{n} \rightarrow f'(x) = \frac{d}{dx} (x^{n}) = n \cdot x^{n-1}  $$

# %%
def diff(x):
    h=0.000001
    return (f(x+h)-f(x))/h

# %%
def f(x): return x**2

# %%
import sympy as sp
x=sp.symbols('x')
f=x**2
f_prime = sp.diff(f,x)
f_prime
# Out:
# 2*x

# %%
import sympy as sp
x=sp.symbols('x')
f=3*x**7
f_prime = sp.diff(f,x)
f_prime
# Out:
# 21*x**6

# %%
x_values = np.linspace(-10, 10, 400)
y_values = diff(x_values)
ori_fn_values = f(x_values)
plt.figure(figsize=(8,6))
plt.plot(x_values,y_values, label='f\'(x)')
plt.plot(x_values,ori_fn_values, label='f(x)')
plt.xlabel('X')
plt.ylabel('f\'(x)')
plt.title("derivative function")
plt.legend()
plt.grid(True)
plt.show()

# %%
obj2={
    "이름":["홍길동","김말자","인순이","태진아","김말자"],
    "수학":[98,34,67,99,63],
    "영어":[98,34,67,99,22],
    "미술":[98,34,67,99,33],
    "도덕":[98,34,67,99,77]}
df=pd.DataFrame(obj2)
df.head(1)
# Out:
#     이름  수학  영어  미술  도덕
# 0  홍길동  98  98  98  98

# %%
df[df['이름'] == "김말자"]
# Out:
#     이름  수학  영어  미술  도덕
# 1  김말자  34  34  34  34
# 4  김말자  63  22  33  77

# %%
df[df['미술'] >= 60]
# Out:
#     이름  수학  영어  미술  도덕
# 0  홍길동  98  98  98  98
# 2  인순이  67  67  67  67
# 3  태진아  99  99  99  99
